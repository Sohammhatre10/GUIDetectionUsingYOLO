# %% [markdown]
# <a href="https://colab.research.google.com/github/Sohammhatre10/GUIDetectionUsingYOLO/blob/main/GUIDetectionUsingYOLO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gdown
import gdown

url_input_file = "https://drive.google.com/file/d/18po-DwmihIpZZXleSPX0NLpivXl-G3c7/view?usp=drive_link"

url = "https://drive.google.com/uc?id=1ESuuQE6uy3G-XlvkSBolZV_TZz4WAvQf"
output = "/content/file.zip"
gdown.download(url, output, quiet=False)
gdown.download(url_input_file, "/content/input_image.png", quiet=False)

# !unzip /content/file.zip
# Out:
# ...
# Downloading...
# From (original): https://drive.google.com/uc?id=1ESuuQE6uy3G-XlvkSBolZV_TZz4WAvQf
# From (redirected): https://drive.google.com/uc?id=1ESuuQE6uy3G-XlvkSBolZV_TZz4WAvQf&confirm=t&uuid=8fb7cb0e-5adc-4379-9c26-459798be8d57
# To: /content/file.zip
# 100%|██████████| 479M/479M [00:03<00:00, 137MB/s]
# /usr/local/lib/python3.10/dist-packages/gdown/parse_url.py:44: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=18po-DwmihIpZZXleSPX0NLpivXl-G3c7
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/file/d/18po-DwmihIpZZXleSPX0NLpivXl-G3c7/view?usp=drive_link
# To: /content/input_image.png
# 82.7kB [00:00, 367MB/s]
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/uplabs_272_jpg.rf.5f2c50c75b46039487f7377689f290be.jpg
# ...

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.8/750.8 kB 11.2 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %% [markdown]
# Get the YOLO model by Ultrlytics which is an open source model used for wide variety of computer vision tasks.

# %% [markdown]
# Import YOLO here

# %%
model = YOLO('yolov9c.pt')
# Out:
# ...
# 100%|██████████| 49.4M/49.4M [00:00<00:00, 222MB/s]

# %% [markdown]
# ```Use the Yolov9c.pt model according to ```
# ↪[*YOLO Docs*](https://docs.ultralytics.com/models/yolov9/#usage-examples)

# %%
# !unzip "/content/drive/MyDrive/ATGTASK/gui elemss.v1i.yolov9.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: train/images/uplabs_272_jpg.rf.5f2c50c75b46039487f7377689f290be.jpg
#  extracting: train/images/uplabs_273_jpg.rf.3ab1547d9592c0e60cd4b373f08fef27.jpg
#  extracting: train/images/uplabs_274_jpg.rf.c92a29e64adc4d825b2858cecb6c547e.jpg
#  extracting: train/images/uplabs_276_jpg.rf.745d5811168ab9943ab54d9b43c3c8bb.jpg
#  extracting: train/images/uplabs_278_jpg.rf.e88d61589708c2d62e7bc37d108cf4c7.jpg
#  extracting: train/images/uplabs_280_jpg.rf.695cc0c909359b70c11b65ae93af5118.jpg
#  extracting: train/images/uplabs_281_jpg.rf.d07921a36734d1c628be3766a6e0cd49.jpg
#  extracting: train/images/uplabs_285_jpg.rf.7e90c81009074b0e1eedf1ac7a451f45.jpg
#  extracting: train/images/uplabs_286_jpg.rf.eed084d0d4400397d1b1a4f65e19a01f.jpg
#  extracting: train/images/uplabs_287_jpg.rf.deca8a48ad0be437a6980c0c00fa4db5.jpg
#  extracting: train/images/uplabs_288_jpg.rf.80449c591698d1b3da3d8cad4228c9a8.jpg
# ...

# %%
# !touch data.yaml

# %% [markdown]
# ### Use data.yaml for entering the files used
#
#
# ```
# train : train_path
# test : test_path
# valid : valid_path
#
# nc : labels
#
# names: ['BackgroundImage', 'CheckedTextView', 'EditText', 'Icon', 'Image', 'Modal', 'PageIndicator', 'Switch', 'Text', 'TextButton', 'Toolbar', 'UpperTaskBar']
# ```

# %%
model.train(data= "/content/data.yaml", epochs=5)
# Out:
# Ultralytics YOLOv8.2.2 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# ```
# Train the model here using the best.pt from run/detect/
# ```

# %%
actual_model = YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
actual_model.predict("/content/test/images/10107_jpg.rf.959d23901c8686f189dbb2811fc85008.jpg")
# Out:
# image 1/1 /content/test/images/10107_jpg.rf.959d23901c8686f189dbb2811fc85008.jpg: 640x416 1 Icon, 1 Modal, 9 Texts, 2 TextButtons, 1 Toolbar, 1 UpperTaskBar, 169.6ms
# Speed: 3.4ms preprocess, 169.6ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 416)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BackgroundImage', 1: 'CheckedTextView', 2: 'EditText', 3: 'Icon', 4: 'Image', 5: 'Modal', 6: 'PageIndicator', 7: 'Switch', 8: 'Text', 9: 'TextButton', 10: 'Toolbar', 11: 'UpperTaskBar'}
#  obb: None
#  orig_img: array([[[2, 0, 0],
#          [2, 0, 0],
#          [2, 0, 0],
#          ...,
#          [2, 0, 0],
#          [2, 0, 0],
#          [2, 0, 0]],
#
#         [[2, 0, 0],
#          [2, 0, 0],
#          [2, 0, 0],
#          ...,
#          [2, 0, 0],
#          [2, 0, 0],
#          [2, 0, 0]],
#
#         [[2, 0, 0],
#          [2, 0, 0],
# ...

# %%
actual_model.predict("/content/test/images", save=True, save_txt=True)
# Out:
# image 1/453 /content/test/images/10107_jpg.rf.959d23901c8686f189dbb2811fc85008.jpg: 640x416 1 Icon, 1 Modal, 9 Texts, 2 TextButtons, 1 Toolbar, 1 UpperTaskBar, 41.3ms
# image 2/453 /content/test/images/10624_jpg.rf.9ba12f9c676c96516c953128fec3c097.jpg: 640x416 1 BackgroundImage, 1 Icon, 1 Image, 3 Texts, 2 TextButtons, 1 UpperTaskBar, 35.4ms
# image 3/453 /content/test/images/1073_jpg.rf.732914bbd53179fb3484c139c8cec6dd.jpg: 640x416 3 CheckedTextViews, 4 Icons, 1 Image, 1 Modal, 19 Texts, 2 TextButtons, 1 Toolbar, 1 UpperTaskBar, 35.3ms
# image 4/453 /content/test/images/11290_jpg.rf.284659f44dafbef519ad948f9e1e3be5.jpg: 640x416 1 Image, 1 PageIndicator, 2 Texts, 2 TextButtons, 1 UpperTaskBar, 35.7ms
# image 5/453 /content/test/images/11532_jpg.rf.5fa18f37f0b283f10d43bc51c9b25875.jpg: 640x416 1 PageIndicator, 3 Texts, 2 TextButtons, 1 UpperTaskBar, 35.3ms
# ...

# %%
actual_model.predict("/content/input_image.png", save=True)
# Out:
# image 1/1 /content/Screenshot 2024-04-20 012307.png: 640x320 1 EditText, 5 Icons, 6 Images, 1 PageIndicator, 8 Texts, 41.3ms
# Speed: 2.4ms preprocess, 41.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 320)
# Results saved to runs/detect/predict
# 454 labels saved to runs/detect/predict/labels
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'BackgroundImage', 1: 'CheckedTextView', 2: 'EditText', 3: 'Icon', 4: 'Image', 5: 'Modal', 6: 'PageIndicator', 7: 'Switch', 8: 'Text', 9: 'TextButton', 10: 'Toolbar', 11: 'UpperTaskBar'}
#  obb: None
#  orig_img: array([[[ 30,  30,  30],
#          [ 30,  30,  30],
#          [ 30,  30,  30],
#          ...,
#          [ 30,  30,  30],
#          [ 30,  30,  30],
#          [ 30,  30,  30]],
#
#         [[ 30,  30,  30],
#          [ 30,  30,  30],
#          [ 30,  30,  30],
#          ...,
# ...

# %%
from IPython.display import Image
input_image = Image("input_image.png")
input_image

# %%
output_image = Image(f"/content/runs/detect/predict/input_image.png")
output_image

# %%
# Insert File_name for the screenshot and generate the output

# %%
input_file_new = input("Upload the file and then copy its path in the input field here")
output_file_new = actual_model.predict(input_file_new, save=True)
output_file_new
